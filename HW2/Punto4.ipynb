# %%
import os
import os.path as op
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from textblob import TextBlob

en_stopwords = set((stopwords.words('english')))
es_stopwords = set((stopwords.words('spanish')))
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
from nltk.stem import SnowballStemmer

es_stemmer = SnowballStemmer('spanish')
import math
import re

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn import preprocessing

# %% [markdown]
# # Utils for text processing and lexicon creating

# %%
import nltk
from textblob import TextBlob
from nltk.corpus import stopwords
en_stopwords = set((stopwords.words('english')))
es_stopwords = set((stopwords.words('spanish')))
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
from nltk.stem import SnowballStemmer
es_stemmer = SnowballStemmer('spanish')

import re

def to_lower(word):
    '''
    word: str, string of a single word
    This function returns the lower case of the given word
    '''
    result = word.lower()
    return result

def remove_mentions(word):
    '''
    word: str, string of a single word
    Removes mentions in tweets, they are recognized via the @ character
    '''
    result = re.sub(r"@\S+","",word)
    return result

def remove_number(word):
    '''
    word: str, string of a single word
    Removes numbers in tweets
    '''
    result = re.sub(r'\d+', '', word)
    return result

def remove_punctuation(word):
    '''
    word: str, string of a single word
    Removes punctuation characters of a string
    '''
    result = re.sub('[^A-Za-z]+', ' ', word)
    return result


def clean_text(raw_text):
    emoji_pat = '[\U0001F300-\U0001F64F\U0001F680-\U0001F6FF\u2600-\u26FF\u2700-\u27BF]'
    shrink_whitespace_reg = re.compile(r'\s{2,}')
    reg = re.compile(r'({})|[^a-zA-Z]'.format(emoji_pat)) # line a
    result = reg.sub(lambda x: ' {} '.format(x.group(1)) if x.group(1) else ' ', raw_text)
    return shrink_whitespace_reg.sub(' ', result)

def remove_en_stopwords(words):
    '''
    words: list of str, list containing the str for every word in the tweet
    stop_words: List of str, list containing all stop words for a given language
    Removes stop words in the tweet
    '''
    result = [i for i in words if i not in en_stopwords]      
    return result

def remove_es_stopwords(words):
    '''
    words: list of str, list containing the str for every word in the tweet
    stop_words: List of str, list containing all stop words for a given language
    Removes stop words in the tweet
    '''
    result = [i for i in words if i not in es_stopwords]      
    return result

def remove_stopwords(words,stopwords):
    '''
    words: list of str, list containing the str for every word in the tweet
    stop_words: List of str, list containing all stop words for a given language
    Removes stop words in the tweet
    '''
    result = [i for i in words if i not in stopwords]      
    return result

def remove_hyperlink(word):
    '''
    word: str, string of a single word
    Removes URLs in the given word
    '''
    return re.sub(r"http\S+", "", word)

def remove_whitespace(word):
    '''
    word: str, string of a single word
    Removes whitespaces from a str
    '''
    result = word.strip()
    return result

def replace_newline(word):
    '''
    word: str, string of a single word
    Removes new lines from a str
    '''
    return word.replace('\n','')

def clean_up_pipeline(sentence, keep_emojis=True):
    '''
    sentence: str, string containing the tweet
    keep_emojis: boolean, boolean that indicates if the emojis want to be kept in the tweets
    This function cleans up the tweets with previous functions
    '''
    if keep_emojis:
        cleaning_data = [remove_hyperlink,
                        replace_newline,
                        to_lower,
                        clean_text,
                        remove_mentions,
                        remove_number,
                        remove_whitespace]
        for func in cleaning_data:
            
            sentence = func(sentence)
    else:
        cleaning_data = [remove_hyperlink,
                        replace_newline,
                        to_lower,
                        remove_punctuation,
                        remove_mentions,
                        remove_number,
                        remove_punctuation,
                        remove_whitespace]
        for func in cleaning_data:
            
            sentence = func(sentence) 
    return sentence


def stem_words(text,lang):
    '''
    text: list of str, list of tokens to be stemmed
    lang: str, 'en' for english, 'es' for spanish
    Returns the list of stemmed tokens according to the given language
    '''
    if lang == 'en':     
        text = [stemmer.stem(word) for word in text]
    else:
        text = [es_stemmer.stem(word) for word in text]
    return text

def create_term_index(token_docs):
    '''
    token_docs: list of lists that contain the tokens for each document
    Returns the unique token vocabulary for the given document tokens
    '''
    terms = [item for sublist in token_docs for item in sublist]
    terms = sorted(list(set(terms)))
    return terms

def get_topwords(df,number):
    '''
    df: DataFrame containing the tokens as index and the lexicon score of each token
    number: int, number of top words to be returned
    Returns a df of the top words according to the lexicon score
    '''
    df = df.sort_values(by=['score'],ascending=False)
    df = df.head(number).loc[:,['score']]
    return df

def get_dictionary(df):
    '''
    df: DataFrame containing the tokens as index and the lexicon score of each token
    Returns the lexicon in dictionary form
    '''
    df = df.sort_index()
    df = df.loc[:,['score']]
    dic = df.to_dict()
    return dic

# %% [markdown]
# # Functions for the processing of features for models and the training and results

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.inspection import permutation_importance

def count_words_dictionary(list_tokens,dic):
    '''
    list_tokens: list containing the tokens for each document
    dic: dictionary, dictionary containing the lexicon
    Returns the count of tokens from the doc in the given lexicon dictionary
    '''
    counter = 0
    for token in list_tokens:
        if token in dic['score']:
            counter += 1
    return counter

def sum_words_dictionary(list_tokens,dic):
    '''
    list_tokens: list containing the tokens for each document
    dic: dictionary, dictionary containing the lexicon
    Returns the sum of tokens lexicon values from the doc in the given lexicon dictionary
    '''
    counter = 0
    for token in list_tokens:
        if token in dic['score']:
            counter = counter + dic['score'][token]
    return counter

def create_features(df,mourn_dic,nomourn_dic):
    '''
    df: DataFrame, that contains the list of tokens for each document in the text column
    mourn_dic: dictionary, mourning lexicon
    nomourn_dic: dictionary, no mourning lexicon
    
    For the given DataFrame creates the designed feature columns, returns the DataFrame
    '''
    df['NUM_TOKENS'] = df['text'].apply(lambda text: len(text))
    df['COUNT_MOURN'] = df['text'].apply(lambda text: count_words_dictionary(text,mourn_dic))
    df['SUM_MOURN'] = df['text'].apply(lambda text: sum_words_dictionary(text,mourn_dic))
    df['COUNT_NOMOURN'] = df['text'].apply(lambda text: count_words_dictionary(text,nomourn_dic))
    df['SUM_NOMOURN'] = df['text'].apply(lambda text: sum_words_dictionary(text,nomourn_dic))
    df['MOURN_PERC'] = df['COUNT_MOURN']/df['NUM_TOKENS']
    df['NOMOURN_PERC'] = df['COUNT_NOMOURN']/df['NUM_TOKENS']
    return df

def process_df(df,cols):
    '''
    df: DataFrame, that contains the features and the target variable
    cols: list, list containing the features and the target variable
    
    Returns X and y for a classifier model from the dataframe, where X are the features
    and y is the target var binarized
    '''
    df['Y']=np.where(df['tag'] == 'mourning',1,0)
    df=df.loc[:,cols]
    y = df['Y']
    X = df.drop(['Y'],axis=1).fillna(0)
    return X,y

def train_model(X,y,seed,test_prop,model):
    '''
    X: DataFrame containing the features
    y: Pandas Series containing the binarized target variable
    seed: int, seed for random states
    test_prop: float, proportion wanted for the test set
    model: str, str containing the model that is wanted. 'NB': Naive Bayes, 'LR': Logistic Regression,
    'DT': Decision Tree, 'RF': Random Forest
    
    Returns the predictions for the test set, the test set real values and the trained model
    '''
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=seed,test_size=test_prop)
    if model == 'NB':
        clf = GaussianNB()
    elif model == 'LR':
        clf = LogisticRegression(random_state=seed)
    elif model == 'DT':
        clf = DecisionTreeClassifier(random_state=seed)
    else:
        clf = RandomForestClassifier(random_state=seed)    
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    return y_pred, y_test, clf

def get_results(X,y,seed,test_prop):
    '''
    X: DataFrame containing the features
    y: Pandas Series containing the binarized target variable
    seed: int, seed for random states
    test_prop: float, proportion wanted for the test set
    
    Returns the results for each model that contains the evaluation metrics in a DataFrame for visualization
    '''
    model_list = ['NB','LR','DT','RF']
    result = pd.DataFrame(columns=['Model','Precision','Recall','F1 Score'])
    for model in model_list:
        y_pred_proba, y_test,_ = train_model(X,y,seed,test_prop,model)
        y_pred = np.where(y_pred_proba>=0.5,1,0)
        prec = precision_score(y_test,y_pred)
        recall = recall_score(y_test,y_pred)
        f1 = f1_score(y_test,y_pred)
        dictionary_results = {'Model': model, 'Precision': prec, 'Recall': recall,
                          'F1 Score': f1}
        
        result = result.append(dictionary_results, ignore_index=True)
    
    return result

def get_rfimportance(X,y,seed,test_prop):
    '''
    X: DataFrame containing the features
    y: Pandas Series containing the binarized target variable
    seed: int, seed for random states
    test_prop: float, proportion wanted for the test set
    
    Returns the importance of each feature for a trained random forest model    
    '''
    X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=seed,test_size=test_prop)
    clf = RandomForestClassifier(random_state=seed)    
    clf.fit(X_train,y_train)
    r = permutation_importance(clf,X_test,y_test)
    return r

# %%
df = pd.read_csv(r'C:/Users/Jaime.Acevedo/Documents/Jd/Maestría JD/NLP/HW02/fnmourning.csv')
df
# Out:
#                                                     text          tag lang  \
# 0      Hoy uno de mis tíos falleció por COVID-19, no ...     mourning   es
# 1      Hoy falleció mi abuela. Y eso, sin velorio, si...     mourning   es
# 2      Muere el primer médico en activo por Covid-19 ...     mourning   es
# 3      Historia de una victoria. Historia de los últi...     mourning   es
# 4      He visto dos personas a las que les tomé cariñ...     mourning   es
# ...                                                  ...          ...  ...
# 24580  Ontario health-care worker who dedicated 31 ye...  no mourning   en
# 24581  La carita triste de coronavirus, encierro, let...  no mourning   es
# 24582               @EvaR001 Me da: vergüenza JAJAJAJAJA  no mourning   es
# 24583  @History_LigaMX @atlasfc @Rayados @FCTecos @Cl...  no mourning   es
# 24584  @MattHancock @BorisJohnson Out of the ashes of...  no mourning   en
#
#        emoticon
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 24580         0
# 24581         0
# 24582         0
# 24583         0
# 24584         0
#
# [24585 rows x 4 columns]

# %%
df['text'] = df['text'].apply(lambda text: clean_up_pipeline(text,keep_emojis=True))
df['text'] = df['text'].apply(word_tokenize)

df_en = df.loc[df['lang']=='en']
df_es = df.loc[df['lang']=='es']

df_en['text'] = df_en['text'].apply(lambda text: remove_stopwords(text,en_stopwords))
df_es['text'] = df_es['text'].apply(lambda text: remove_stopwords(text,es_stopwords))

df_en['text'] = df_en['text'].apply(lambda text: stem_words(text,'en'))
df_es['text'] = df_es['text'].apply(lambda text: stem_words(text,'es'))

data_en = list(zip(df_en.index,df_en['text']))
data_es = list(zip(df_es.index,df_es['text']))

list_tweets_processed = []
for id, text in data_en:
    list_tweets_processed.append(text)

list_tweets_processed_es = []
for id, text in data_es:
    list_tweets_processed_es.append(text)

vocabulary_en = create_term_index(list_tweets_processed)
vocabulary_es = create_term_index(list_tweets_processed_es)

vocabulary_en[-50:]
# Out:
# <ipython-input-5-9a85522836f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['text'] = df_en['text'].apply(lambda text: remove_stopwords(text,en_stopwords))
# <ipython-input-5-9a85522836f1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_es['text'] = df_es['text'].apply(lambda text: remove_stopwords(text,es_stopwords))
# <ipython-input-5-9a85522836f1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['text'] = df_en['text'].apply(lambda text: stem_words(text,'en'))
# <ipython-input-5-9a85522836f1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_es['text'] = df_es['text'].apply(lambda text: stem_words(text,'es'))
# ['😬',
#  '😭',
#  '😮',
#  '😯',
#  '😰',
#  '😱',
#  '😲',
#  '😳',
#  '😴',
#  '😶',
#  '😷',
#  '😹',
#  '😻',
#  '😼',
#  '😽',
#  '😿',
#  '🙁',
#  '🙂',
#  '🙃',
#  '🙄',
#  '🙅',
#  '🙆',
#  '🙇',
#  '🙈',
#  '🙉',
#  '🙊',
#  '🙋',
#  '🙌',
#  '🙍',
#  '🙎',
#  '🙏',
#  '🚀',
#  '🚆',
#  '🚑',
#  '🚒',
#  '🚔',
#  '🚙',
#  '🚜',
#  '🚣',
#  '🚦',
#  '🚨',
#  '🚪',
#  '🚫',
#  '🚭',
#  '🚮',
#  '🚶',
#  '🛌',
#  '🛍',
#  '🛏',
#  '🛒']

# %%
def get_nb_results(list_tweets,df,vocabulary):
    '''
    list_tweets: list of lists containing the tokens for each document
    df: DataFrame containing the the text for each document and the tag
    vocabulary: list, vocabulary of tokens
    
    Function that does the pipeline for the Naive Bayes results, it takes the DataFrame separates into
    mourning and no mourning tweets. Gets the vocabulary for both tags, and finally scores the nb value
    for each token in each class.
    
    Returns the mourn NB tokens and values in a DataFrame, the not mourn NB tokens and values in a DataFrame,
    and the full vocabulary with the NB values for both classes and the tag column where the class is decided:
    if MournNB > NoMournNB then mourning else no mourning
    '''
    mlb = MultiLabelBinarizer()
    mlb.fit(list_tweets)

    df_en_m = df.loc[df['tag']=='mourning']
    df_en_nom = df.loc[df['tag']=='no mourning']

    data_en_mourn = list(zip(df_en_m.index,df_en_m['text']))

    list_tweets_processed_mourn = []
    for id, text in data_en_mourn:
        list_tweets_processed_mourn.append(text)

    X_en_mourn = mlb.transform(list_tweets_processed_mourn)
    english_mourn = pd.DataFrame(X_en_mourn, columns = mlb.classes_).T

    data_en_nomourn = list(zip(df_en_nom.index,df_en_nom['text']))

    list_tweets_processed_nomourn = []
    for id, text in data_en_nomourn:
        list_tweets_processed_nomourn.append(text)

    X_en_nomourn = mlb.transform(list_tweets_processed_nomourn)
    english_nomourn = pd.DataFrame(X_en_nomourn, columns = mlb.classes_).T

    pmourn = np.log(sum(df['tag']=='mourning')/len(df['tag']))
    pnomourn = np.log(sum(df['tag']=='no mourning')/len(df['tag']))

    vocabulary_en_mourn = create_term_index(list_tweets_processed_mourn)
    vocabulary_en_nomourn = create_term_index(list_tweets_processed_nomourn)

    wic_en_mourn = (english_mourn.sum(axis=1)+1)/(len(vocabulary_en_mourn)+len(vocabulary))
    wic_en_nomourn = (english_nomourn.sum(axis=1)+1)/(len(vocabulary_en_nomourn)+len(vocabulary))

    nb_en = pd.DataFrame(dict(wic_en_mourn = wic_en_mourn, wic_en_nomourn = wic_en_nomourn)).reset_index()
    nb_en['wic_en_mourn'] = np.log(nb_en['wic_en_mourn']) 
    nb_en['wic_en_nomourn'] = np.log(nb_en['wic_en_nomourn'])
    nb_en['nb_mourn'] = pmourn + nb_en['wic_en_mourn']
    nb_en['nb_nomourn'] = pnomourn + nb_en['wic_en_nomourn']

    nb_en['nb_class'] = np.where(nb_en['nb_mourn']>nb_en['nb_nomourn'],'mourning','no mourning')

    mourn_nb = nb_en[nb_en['nb_class'] == 'mourning'].loc[:,['index','nb_mourn']].sort_values(by=['nb_mourn'],ascending=False).set_index('index')
    nomourn_nb = nb_en[nb_en['nb_class'] == 'no mourning'].loc[:,['index','nb_nomourn']].sort_values(by=['nb_nomourn'],ascending=False).set_index('index')
    return mourn_nb, nomourn_nb, nb_en

# %%
mourn_nb_en, nomourn_nb_en, nb_en = get_nb_results(list_tweets_processed,df_en,vocabulary_en)
mourn_nb_es, nomourn_nb_es, nb_es = get_nb_results(list_tweets_processed_es,df_es,vocabulary_es)

mourn_nb_en
# Out:
#                nb_mourn
# index
# rip           -3.654761
# famili        -4.202549
# die           -4.298580
# peac          -4.339025
# condol        -4.367735
# ...                 ...
# immol        -10.388758
# immirashraf  -10.388758
# imjuliacitro -10.388758
# iminmyown    -10.388758
# 🚮            -10.388758
#
# [7150 rows x 1 columns]

# %% [markdown]
# This next blocks transform the lexicon to a scaled value between 0 and 1

# %%
scaler = preprocessing.MinMaxScaler()
es_scaler = preprocessing.MinMaxScaler()

mourn_nb_en['score'] = scaler.fit_transform(mourn_nb_en)
nomourn_nb_en['score'] = scaler.transform(nomourn_nb_en)

mourn_nb_es['score'] = es_scaler.fit_transform(mourn_nb_es)
nomourn_nb_es['score'] = es_scaler.transform(nomourn_nb_es)

mourn_nb_en
# Out:
#                nb_mourn     score
# index
# rip           -3.654761  1.000000
# famili        -4.202549  0.918653
# die           -4.298580  0.904393
# peac          -4.339025  0.898387
# condol        -4.367735  0.894123
# ...                 ...       ...
# immol        -10.388758  0.000000
# immirashraf  -10.388758  0.000000
# imjuliacitro -10.388758  0.000000
# iminmyown    -10.388758  0.000000
# 🚮            -10.388758  0.000000
#
# [7150 rows x 2 columns]

# %% [markdown]
# # Top 25 and 40 English mourn terms

# %%
plt.figure()
words = get_topwords(mourn_nb_en,25)
words.plot(kind='bar')
plt.show()
# Out:
# C:\Users\Jaime.Acevedo\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jaime.Acevedo\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128591 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure()
words = get_topwords(mourn_nb_en,40)
words.plot(kind='bar')
plt.show()

# %% [markdown]
# # Top 25 and 40 spanish mourn terms

# %%
plt.figure()
words = get_topwords(mourn_nb_es,25)
words.plot(kind='bar')
plt.show()

# %%
plt.figure()
words = get_topwords(mourn_nb_es,40)
words.plot(kind='bar')
plt.show()

# %% [markdown]
# It can be noted that the mayority of words coicide in their translations for both lexicons, among those are: condolences, family, rip (qepd or dep), rest, death. Most of the top 5 are the same as well.
#
# The biggest difference comes in terms that are not correctly stemmed in the spanish lexicon, this is understandable given that stemming algorithms for english are further developed that algorithms for spanish. Some of the examples among the top 50 in spanish are the letters s, m, p, and d that all appear as important terms.
#
# Additionally we can see some emoticons making the top terms for the mourning lexicon. Between those we can see the heart emoji for the english case, and the pray emoji for both languages.

# %% [markdown]
# Creating lexicon dictionaries for mourning and not mourning for both languages

# %%
dict_mourn_en = get_dictionary(mourn_nb_en)
dict_nomourn_en = get_dictionary(nomourn_nb_en)
dict_mourn_es = get_dictionary(mourn_nb_es)
dict_nomourn_es = get_dictionary(nomourn_nb_es)

dict_mourn_en
# Out:
# {'score': {'aaaaaaaand': 0.0,
#   'aaaaw': 0.0,
#   'aal': 0.0,
#   'aaliyah': 0.06021165601161149,
#   'aan': 0.0,
#   'aap': 0.0,
#   'aapko': 0.0,
#   'aaron': 0.0,
#   'aatmanirbharbharatmor': 0.13606937132434216,
#   'abakaliki': 0.0,
#   'abatcha': 0.0,
#   'abbot': 0.0,
#   'abd': 0.0,
#   'abdel': 0.0,
#   'abdelfattah': 0.16314416183443115,
#   'abdelmadjid': 0.0,
#   'abdiqani': 0.0,
#   'abdrabbo': 0.16314416183443115,
#   'abdul': 0.06021165601161149,
#   'abdullahi': 0.0,
#   'abe': 0.10293250582281965,
#   'abia': 0.0,
#   'abid': 0.0,
#   'abject': 0.0,
#   'abl': 0.4448668887928011,
#   'aboard': 0.0,
#   'abod': 0.0,
#   'abscbn': 0.0,
#   'abscbnfranchis': 0.0,
#   'absenc': 0.06021165601161149,
#   'absenteeadam': 0.0,
#   'absolut': 0.46235769499320467,
#   'abteach': 0.0,
#   'abu': 0.0,
#   'abudhabi': 0.0,
#   'abuelita': 0.0,
#   'abuelito': 0.0,
#   'aburizalbakri': 0.0,
#   'abuti': 0.0,
#   'academ': 0.16314416183443115,
#   'academia': 0.06021165601161149,
#   'acanadianinusa': 0.0,
#   'acc': 0.06021165601161149,
#   'acccgovau': 0.0,
#   'accept': 0.34193438296998147,
#   'accid': 0.16314416183443115,
#   'accomed': 0.0,
#   'accomplic': 0.0,
#   'accomplish': 0.06021165601161149,
#   'ach': 0.10293250582281965,
#   'achil': 0.0,
#   'acknowledg': 0.18603557103859614,
#   'aclu': 0.0,
#   'acoust': 0.0,
#   'acquaint': 0.06021165601161149,
#   'act': 0.40214603898159296,
#   'activewear': 0.0,
#   'actor': 0.36268906155890424,
#   'actress': 0.2058650116456393,
#   'adam': 0.22335581784604286,
#   'adamjwest': 0.0,
#   'adamu': 0.06021165601161149,
#   'adana': 0.0,
#   'add': 0.2390018771471618,
#   'addi': 0.13606937132434216,
#   'addiem': 0.0,
#   'ade': 0.0,
#   'adeypop': 0.0,
#   'adi': 0.0,
#   'adijoseph': 0.0,
#   'adityanathji': 0.06021165601161149,
#   'administr': 0.455606522636715,
#   'admir': 0.10293250582281965,
#   'admit': 0.2779630270117315,
#   'admitt': 0.0,
#   'adoni': 0.0,
#   'adrian': 0.0,
#   'advanc': 0.2058650116456393,
#   'advoc': 0.2390018771471618,
#   'aemat': 0.0,
#   'aengel': 0.0,
#   'aesthet': 0.0,
#   'afar': 0.06021165601161149,
#   'affect': 0.49746147952405906,
#   'afg': 0.0,
#   'aflcio': 0.0,
#   'afraid': 0.13606937132434216,
#   'afreepressmatt': 0.0,
#   'africanamerican': 0.0,
#   'africanlegend': 0.0,
#   'africanmus': 0.06021165601161149,
#   'afrobeat': 0.06021165601161149,
#   'afterlif': 0.06021165601161149,
#   'afterlifeif': 0.0,
#   'afternoon': 0.22335581784604286,
#   'afterprohibend': 0.0,
#   'afterschool': 0.0,
#   'afthunderbird': 0.0,
#   'afua': 0.10293250582281965,
#   'afzal': 0.06021165601161149,
#   'ag': 0.0,
#   'age': 0.6016909387060662,
#   'agedcar': 0.0,
#   'aggriev': 0.0,
#   'agnezmo': 0.0,
#   'ago': 0.5099478405662885,
#   'agoguess': 0.0,
#   'agoni': 0.10293250582281965,
#   'agreat': 0.0,
#   'agribruc': 0.0,
#   'agyei': 0.0,
#   'ahddrv': 0.0,
#   'ahhhhh': 0.0,
#   'ahhhhhhhhh': 0.0,
#   'ahmad': 0.10293250582281965,
#   'ahmaud': 0.18603557103859614,
#   'ahmaudarberi': 0.13606937132434216,
#   'ahmedabad': 0.22335581784604286,
#   'ahmedabadmirror': 0.10293250582281965,
#   'ahshaad': 0.0,
#   'aicc': 0.18603557103859614,
#   'aieshanya': 0.0,
#   'aiet': 0.0,
#   'aileen': 0.0,
#   'aimco': 0.0,
#   'aime': 0.06021165601161149,
#   'aint': 0.06021165601161149,
#   'aircarft': 0.0,
#   'airheadhel': 0.0,
#   'airlangga': 0.0,
#   'ajay': 0.0,
#   'ajaykumar': 0.0,
#   'ajlab': 0.0,
#   'ajmk': 0.0,
#   'ajrbroth': 0.0,
#   'ak': 0.0,
#   'akk': 0.0,
#   'ako': 0.0,
#   'akshaysinghel': 0.0,
#   'al': 0.2889680768614158,
#   'ala': 0.06021165601161149,
#   'alan': 0.10293250582281965,
#   'alannabennett': 0.0,
#   'alarmist': 0.0,
#   'alastairavenir': 0.0,
#   'albani': 0.0,
#   'albert': 0.06021165601161149,
#   'albomp': 0.0,
#   'album': 0.16314416183443115,
#   'alder': 0.0,
#   'aleist': 0.0,
#   'alessandrawc': 0.0,
#   'alexanderkekul': 0.0,
#   'alexandrovskaya': 0.0,
#   'alexey': 0.0,
#   'alexmunt': 0.0,
#   'alexnorrisnn': 0.0,
#   'alfredo': 0.0,
#   'algerian': 0.06021165601161149,
#   'alghurair': 0.0,
#   'ali': 0.2531554594062104,
#   'alich': 0.0,
#   'alipor': 0.0,
#   'alison': 0.22335581784604286,
#   'alisonljon': 0.0,
#   'alistairpetri': 0.0,
#   'aliv': 0.2889680768614158,
#   'aliwazirna': 0.0,
#   'allah': 0.36268906155890424,
#   'allama': 0.0,
#   'alleluia': 0.0,
#   'allen': 0.16314416183443115,
#   'allerton': 0.0,
#   'alleyn': 0.0,
#   'allofitwnyc': 0.0,
#   'allot': 0.0,
#   'almani': 0.0,
#   'almeida': 0.0,
#   'almighti': 0.34193438296998147,
#   'almurray': 0.0,
#   'alon': 0.49215733655337224,
#   'alot': 0.10293250582281965,
#   'alphabet': 0.0,
#   'alr': 0.0,
#   'also': 0.5701594965779001,
#   'altar': 0.10293250582281965,
#   'alternativo': 0.0,
#   'alumni': 0.0,
#   'alvarez': 0.0,
#   'alvi': 0.0,
#   'alwahidah': 0.0,
#   'alway': 0.5895892055419741,
#   'alwayz': 0.0,
#   'alyc': 0.0,
#   'alyssa': 0.0,
#   'ama': 0.0,
#   'amadu': 0.0,
#   'amandacarpent': 0.13606937132434216,
#   'amarujalanew': 0.0,
#   'amaud': 0.0,
#   'amaz': 0.36900917348007045,
#   'amazetv': 0.0,
#   'amazigh': 0.0,
#   'amber': 0.06021165601161149,
#   'ambigu': 0.0,
#   'ambul': 0.2992135331587735,
#   'amdavadamc': 0.0,
#   'ameen': 0.10293250582281965,
#   'amen': 0.3808955328345509,
#   'americanidolstil': 0.0,
#   'americastrong': 0.0,
#   'amethi': 0.0,
#   'ami': 0.10293250582281965,
#   'amidst': 0.2531554594062104,
#   'amigabeanbag': 0.0,
#   'amigo': 0.0,
#   'amin': 0.10293250582281965,
#   'amit': 0.3178002868847398,
#   'amith': 0.0,
#   'amitmalviya': 0.0,
#   'amitrana': 0.18603557103859614,
#   'amm': 0.0,
#   'amoedo': 0.0,
#   'amongst': 0.13606937132434216,
#   'amor': 0.0,
#   'amp': 0.7975409056066965,
#   'amphan': 0.0,
#   'amrik': 0.0,
#   'amyhamilton': 0.0,
#   'ana': 0.0,
#   'anaesthetist': 0.0,
#   'anandmahindra': 0.0,
#   'ananursingworld': 0.0,
#   'anbalagan': 0.0,
#   'ancestr': 0.06021165601161149,
#   'anderson': 0.10293250582281965,
#   'andgordon': 0.0,
#   'andhara': 0.0,
#   'andhrapradesh': 0.06021165601161149,
#   'andhrapradeshcm': 0.0,
#   'andi': 0.2992135331587735,
#   'andr': 0.10293250582281965,
#   'andra': 0.06021165601161149,
#   'andrea': 0.2531554594062104,
#   'andreabulma': 0.0,
#   'andrearussett': 0.0,
#   'andreatalkslaw': 0.0,
#   'andreffrenett': 0.0,
#   'andreharrel': 0.06021165601161149,
#   'andrew': 0.22335581784604286,
#   'andrewcuomo': 0.0,
#   'andrewghenley': 0.0,
#   'andrewlamb': 0.0,
#   'andrewyang': 0.0,
#   'andydeerman': 0.10293250582281965,
#   'anerlisamuigai': 0.0,
#   'anesthesia': 0.0,
#   'aneurysm': 0.0,
#   'anew': 0.0,
#   'ang': 0.06021165601161149,
#   'angel': 0.43724982351244757,
#   'angeleno': 0.0,
#   'angelicalavito': 0.0,
#   'angelu': 0.0,
#   'angelwhitexo': 0.0,
#   'angi': 0.06021165601161149,
#   'angiestrucklif': 0.0,
#   'anglican': 0.0,
#   'anglicar': 0.0,
#   'angst': 0.0,
#   'angu': 0.0,
#   'anguish': 0.06021165601161149,
#   'aniesbaswedan': 0.0,
#   'anildeshmukhncp': 0.0,
#   'anirevo': 0.0,
#   'anita': 0.13606937132434216,
#   'anitaji': 0.0,
#   'ann': 0.10293250582281965,
#   'anna': 0.10293250582281965,
#   'annapoli': 0.0,
#   'annelis': 0.0,
#   'anniv': 0.0,
#   'annoy': 0.06021165601161149,
#   'annu': 0.0,
#   'anoth': 0.6232853945510436,
#   'ant': 0.0,
#   'anthoni': 0.13606937132434216,
#   'anthonymasoncb': 0.0,
#   'anthonypigeesr': 0.0,
#   'anticip': 0.0,
#   'antifabrasil': 0.0,
#   'antifaintl': 0.0,
#   'antoin': 0.0,
#   'anton': 0.06021165601161149,
#   'anwertoon': 0.0,
#   'anybodi': 0.16314416183443115,
#   'anymor': 0.2390018771471618,
#   'anyway': 0.18603557103859614,
#   'anywher': 0.18603557103859614,
#   'aol': 0.10293250582281965,
#   'aor': 0.0,
#   'aoyagi': 0.13606937132434216,
#   'ap': 0.2058650116456393,
#   'apart': 0.3343173176896279,
#   'aphletik': 0.0,
#   'apko': 0.0,
#   'aplausossanitario': 0.0,
#   'appallingli': 0.0,
#   'appendix': 0.06021165601161149,
#   'applaus': 0.10293250582281965,
#   'appnew': 0.0,
#   'appointe': 0.0,
#   'appreci': 0.40214603898159296,
#   'april': 0.48943248550329344,
#   'apsupreswhit': 0.0,
#   'arberi': 0.18603557103859614,
#   'arcad': 0.0,
#   'archambeaum': 0.0,
#   'archbishop': 0.06021165601161149,
#   'archi': 0.0,
#   'architect': 0.06021165601161149,
#   'archterentiu': 0.06021165601161149,
#   'ardua': 0.0,
#   'arewatwitt': 0.0,
#   'argument': 0.06021165601161149,
#   'aria': 0.0,
#   'arif': 0.0,
#   'arij': 0.06021165601161149,
#   'aris': 0.10293250582281965,
#   'ariwibowo': 0.0,
#   'arlen': 0.10293250582281965,
#   'armi': 0.3491797328730273,
#   'arminlaschet': 0.06021165601161149,
#   'armour': 0.0,
#   'arnab': 0.0,
#   'arnt': 0.0,
#   'aroradewan': 0.0,
#   'arround': 0.0,
#   'arthur': 0.0,
#   'artist': 0.36900917348007045,
#   'asbinberlin': 0.0,
#   'asghar': 0.2889680768614158,
#   'asgharwhat': 0.0,
#   'asha': 0.0,
#   'ashbenzo': 0.0,
#   'ashi': 0.0,
#   'ashley': 0.16314416183443115,
#   'ashleymattingli': 0.0,
#   'ashraf': 0.0,
#   'ashwani': 0.0,
#   'asi': 0.30879751746845896,
#   'asid': 0.13606937132434216,
#   'asit': 0.0,
#   'aski': 0.0,
#   'aslan': 0.10293250582281965,
#   'asli': 0.0,
#   'asongforthem': 0.0,
#   'asphyxi': 0.0,
#   'assail': 0.0,
#   'assampcc': 0.0,
#   'assampolic': 0.0,
#   'assang': 0.06021165601161149,
#   'assembl': 0.16314416183443115,
#   'assign': 0.16314416183443115,
#   'assita': 0.0,
#   'associt': 0.06021165601161149,
#   'assumpt': 0.06021165601161149,
#   'astound': 0.06021165601161149,
#   'astra': 0.0,
#   'astroscounti': 0.0,
#   'astut': 0.06021165601161149,
#   'asya': 0.0,
#   'atahasnain': 0.0,
#   'atalanta': 0.0,
#   'athlet': 0.10293250582281965,
#   'atkin': 0.0,
#   'atl': 0.0,
#   'atriumstrong': 0.0,
#   'attach': 0.06021165601161149,
#   'attempt': 0.3262883236688623,
#   'attitud': 0.18603557103859614,
#   'atwoli': 0.0,
#   'aubreynoronha': 0.0,
#   'auckland': 0.0,
#   'audiard': 0.0,
#   'audiotribut': 0.0,
#   'augustin': 0.10293250582281965,
#   'aunt': 0.4207327927075595,
#   'aunti': 0.34193438296998147,
#   'aur': 0.0,
#   'aurangabad': 0.0,
#   'aurora': 0.0,
#   'auschwitz': 0.10293250582281965,
#   'auschwitzmuseum': 0.0,
#   'aushcuk': 0.0,
#   'aushouselondon': 0.0,
#   'austinjohnplay': 0.0,
#   'austria': 0.0,
#   'aut': 0.2531554594062104,
#   'autochton': 0.0,
#   'autograph': 0.06021165601161149,
#   'auvi': 0.0,
#   'avajoyewjz': 0.0,
#   'avedon': 0.0,
#   'avenu': 0.13606937132434216,
#   'averi': 0.0,
#   'avgeek': 0.0,
#   'avid': 0.0,
#   'aw': 0.4117300232912786,
#   'awa': 0.0,
#   'awalkerinla': 0.0,
#   'award': 0.3262883236688623,
#   'awarde': 0.0,
#   'awasom': 0.0,
#   'away': 0.7445745994981307,
#   'awaycondol': 0.0,
#   'awe': 0.06021165601161149,
#   'awkwardfuneralsong': 0.0,
#   'aww': 0.06021165601161149,
#   'awwww': 0.0,
#   'awwwwh': 0.0,
#   'axelskat': 0.0,
#   'axi': 0.0,
#   'ayangkahiyang': 0.0,
#   'ayeetrain': 0.0,
#   'ayon': 0.0,
#   'ayresom': 0.0,
#   'azusa': 0.0,
#   'ba': 0.13606937132434216,
#   'baaki': 0.0,
#   'babajid': 0.06021165601161149,
#   'babe': 0.06021165601161149,
#   'babi': 0.42503744818575795,
#   'babyfac': 0.0,
#   'bac': 0.0,
#   'backlog': 0.10293250582281965,
#   'backstab': 0.0,
#   'bacuzzi': 0.0,
#   'badaruddin': 0.06021165601161149,
#   'badass': 0.0,
#   'baddruddin': 0.0,
#   'badli': 0.16314416183443115,
#   'badruddin': 0.41629962124064157,
#   'badruddinshaikh': 0.0,
#   'badruddinsheikh': 0.0,
#   'baguio': 0.0,
#   'bagumbayan': 0.0,
#   'bahagyal': 0.10293250582281965,
#   'bahn': 0.0,
#   'bailassangeuk': 0.0,
#   'bailey': 0.0,
#   'baker': 0.10293250582281965,
#   'bald': 0.0,
#   'baldyhe': 0.0,
#   'ballardof': 0.0,
#   'ballislif': 0.0,
#   'balloon': 0.0,
#   'balsam': 0.0,
#   'banago': 0.0,
#   'band': 0.2660766676572508,
#   'bandahomesscam': 0.0,
#   'bandaid': 0.06021165601161149,
#   'banker': 0.0,
#   'bankerpramodlanjekar': 0.0,
#   'bankersnestnewsbyt': 0.0,
#   'bankerudaykamath': 0.10293250582281965,
#   'bant': 0.06021165601161149,
#   'banzai': 0.0,
#   'bar': 0.34193438296998147,
#   'barbara': 0.06021165601161149,
#   'barbarash': 0.0,
#   'barbi': 0.0,
#   'bare': 0.13606937132434216,
#   'barendswereld': 0.0,
#   'barkervillebc': 0.0,
#   'barnet': 0.0,
#   'barown': 0.0,
#   'barral': 0.0,
#   'barre': 0.0,
#   'barri': 0.10293250582281965,
#   'barrieashley': 0.0,
#   'bart': 0.0,
#   'baseless': 0.0,
#   'basementbattl': 0.0,
#   'basil': 0.0,
#   'basilhayden': 0.0,
#   'basir': 0.0,
#   'bastart': 0.0,
#   'basuki': 0.0,
#   'batchmat': 0.0,
#   'batf': 0.0,
#   'batteri': 0.0,
#   'battersea': 0.0,
#   'battl': 0.5532662775650025,
#   'baum': 0.0,
#   'baviera': 0.0,
#   'baybayon': 0.0,
#   'bb': 0.10293250582281965,
#   'bball': 0.0,
#   'bbcbreak': 0.06021165601161149,
#   'bbchw': 0.0,
#   'bbcindonesia': 0.0,
#   'bbcnew': 0.18603557103859614,
#   'bbcradiolinc': 0.0,
#   'bbcscotpolit': 0.0,
#   'bbcurdu': 0.0,
#   'bbcwomanshour': 0.0,
#   'bbcworld': 0.10293250582281965,
#   'bbibbi': 0.0,
#   'bbightvc': 0.0,
#   'bbrook': 0.06021165601161149,
#   'bc': 0.3491797328730273,
#   'bcaa': 0.0,
#   'bchad': 0.0,
#   'bcu': 0.0,
#   'bd': 0.0,
#   'bdutt': 0.0,
#   'beagl': 0.06021165601161149,
#   'bear': 0.35608796522902986,
#   'beard': 0.16314416183443115,
#   'beardown': 0.0,
#   'bearsden': 0.0,
#   'beast': 0.0,
#   'beatti': 0.0,
#   'beattiedoug': 0.0,
#   'beaumont': 0.0,
#   'beauti': 0.5279699540085776,
#   'beautifuk': 0.0,
#   'bebop': 0.0,
#   'becam': 0.2390018771471618,
#   'beck': 0.0,
#   'becoz': 0.0,
#   'bedford': 0.0,
#   'bedsid': 0.06021165601161149,
#   'bedtim': 0.0,
#   'befit': 0.0,
#   'beg': 0.2058650116456393,
#   'begay': 0.0,
#   'begin': 0.3262883236688623,
#   'begum': 0.0,
#   'behav': 0.0,
#   'behold': 0.0,
#   'behrampura': 0.13606937132434216,
#   'beij': 0.2390018771471618,
#   'beingboyci': 0.0,
#   'belgium': 0.0,
#   'belhaven': 0.0,
#   'belief': 0.0,
#   'belikesajj': 0.0,
#   'beliv': 0.0,
#   'bellami': 0.0,
#   'bellbevo': 0.0,
#   'belli': 0.42503744818575795,
#   'bellkenni': 0.0,
#   'bello': 0.0,
#   'bellymujinga': 0.13606937132434216,
#   'belmontuniv': 0.0,
#   'belov': 0.30879751746845896,
#   'bemina': 0.0,
#   'ben': 0.3178002868847398,
#   'benchmarkwod': 0.0,
#   'benedict': 0.0,
#   'bengal': 0.2390018771471618,
#   'bengaluru': 0.0,
#   'benito': 0.0,
#   'benja': 0.0,
#   'benjamin': 0.0,
#   'benjillion': 0.0,
#   'benni': 0.06021165601161149,
#   'bennigno': 0.0,
#   'bennington': 0.0,
#   'benstil': 0.0,
#   'benwilson': 0.0,
#   'benztown': 0.0,
#   'bepa': 0.0,
#   'bereav': 0.41629962124064157,
#   'bereavedmoth': 0.0,
#   'berlin': 0.0,
#   'bermudezwrit': 0.0,
#   'bernardkerik': 0.06021165601161149,
#   'bernstein': 0.0,
#   'berri': 0.0,
#   'bespeak': 0.0,
#   'bessbel': 0.0,
#   'besson': 0.0,
#   'bestfriend': 0.0,
#   'besti': 0.0,
#   'bethenni': 0.0,
#   'betsygervasi': 0.0,
#   'betti': 0.2058650116456393,
#   'bevhoward': 0.0,
#   'bexar': 0.06021165601161149,
#   'beyond': 0.2889680768614158,
#   'bgr': 0.0,
#   'bhagwaan': 0.0,
#   'bhai': 0.06021165601161149,
#   'bhave': 0.16314416183443115,
#   'bhavikakapoor': 0.0,
#   'bhopal': 0.06021165601161149,
#   'bhopalgastragedi': 0.06021165601161149,
#   'bhoypeyechemamata': 0.06021165601161149,
#   'bia': 0.0,
#   'bias': 0.06021165601161149,
#   'biba': 0.0,
#   'biblic': 0.0,
#   'bichi': 0.0,
#   'bidauk': 0.0,
#   'bidenisbettervoteblu': 0.0,
#   'big': 0.4448668887928011,
#   'bigdaddi': 0.0,
#   'bigmonsterlov': 0.0,
#   'bigmouth': 0.0,
#   'bigricanman': 0.10293250582281965,
#   'bikemamadelphia': 0.0,
#   'bild': 0.10293250582281965,
#   'bilingu': 0.0,
#   'billandmari': 0.0,
#   'billgat': 0.13606937132434216,
#   'billi': 0.06021165601161149,
#   'billkristol': 0.0,
#   'billrmcdermott': 0.0,
#   'billycorben': 0.0,
#   'bind': 0.0,
#   'bing': 0.16314416183443115,
#   'binkyjoel': 0.0,
#   'biographi': 0.0,
#   'biopic': 0.0,
#   'biovent': 0.0,
#   'bioweapon': 0.06021165601161149,
#   'birdi': 0.0,
#   'birmingham': 0.06021165601161149,
#   'birx': 0.0,
#   'biryani': 0.0,
#   'bishop': 0.2531554594062104,
#   'bishopoliveto': 0.0,
#   'bitchasschicken': 0.0,
#   'bitchesluvgigi': 0.0,
#   'bite': 0.10293250582281965,
#   'bitter': 0.06021165601161149,
#   'bittersweet': 0.0,
#   'biz': 0.10293250582281965,
#   'bizarr': 0.0,
#   'bizitalk': 0.0,
#   'bjp': 0.18603557103859614,
#   'bjpcoronacorrupt': 0.0,
#   'bjpfail': 0.0,
#   'bjpkupwara': 0.0,
#   'bjpmm': 0.0,
#   'bjpnadia': 0.0,
#   'bjym': 0.0,
#   'blackbeauti': 0.0,
#   'blackberri': 0.06021165601161149,
#   'blackhors': 0.2660766676572508,
#   'blackicon': 0.0,
#   'blacklegend': 0.0,
#   'blackmamba': 0.0,
#   'blackmus': 0.0,
#   'blackout': 0.0,
#   'blackpink': 0.0,
#   'blackqueen': 0.0,
#   'blacktheripp': 0.0,
#   'blamechineseregim': 0.0,
#   'blank': 0.0,
#   'blatantli': 0.0,
#   'blather': 0.0,
#   'blazethemicnyc': 0.0,
#   'bleed': 0.18603557103859614,
#   'blerd': 0.06021165601161149,
#   'bless': 0.5895892055419741,
#   'blidg': 0.0,
#   'blind': 0.06021165601161149,
#   'blip': 0.0,
#   'blitz': 0.0,
#   'blixki': 0.0,
#   'blocktrump': 0.0,
#   'bloke': 0.0,
#   'bloodi': 0.22335581784604286,
#   'bloomex': 0.0,
#   'bloomingdal': 0.06021165601161149,
#   'blue': 0.2531554594062104,
#   'blueangel': 0.0,
#   'blueberri': 0.0,
#   'blueforcorey': 0.0,
#   'bluelivesmatt': 0.10293250582281965,
#   'bluelivesmtr': 0.10293250582281965,
#   'blueski': 0.0,
#   'blyth': 0.0,
#   'bmg': 0.0,
#   'bmi': 0.0,
#   'bo': 0.0,
#   'bob': 0.18603557103859614,
#   'bobbynst': 0.0,
#   'boca': 0.0,
#   'bodycountband': 0.0,
#   'boe': 0.0,
#   'bolton': 0.0,
#   'boltonhospic': 0.0,
#   'bon': 0.0,
#   'bone': 0.13606937132434216,
#   'bong': 0.0,
#   'bongo': 0.0,
#   'bonni': 0.06021165601161149,
#   'boo': 0.06021165601161149,
#   'boogaloo': 0.0,
#   'boogieschnitzel': 0.0,
#   'booker': 0.06021165601161149,
#   'booklet': 0.06021165601161149,
#   'boomer': 0.0,
#   'boost': 0.06021165601161149,
#   'bootleg': 0.0,
#   'bootsiebarn': 0.0,
#   'border': 0.3343173176896279,
#   'bordermajor': 0.06021165601161149,
#   'bordersecurityforc': 0.0,
#   'borishasfail': 0.0,
#   'borisjohnsonspeech': 0.0,
#   'borisresigncoronaviru': 0.0,
#   'boro': 0.0,
#   'bostondotcom': 0.0,
#   'bother': 0.16314416183443115,
#   'bottin': 0.0,
#   'bottomless': 0.0,
#   'boundari': 0.0,
#   'bowl': 0.06021165601161149,
#   'bowman': 0.0,
#   'box': 0.3262883236688623,
#   'boxer': 0.18603557103859614,
#   'boxset': 0.0,
#   'boyc': 0.06021165601161149,
#   'boycottmulan': 0.0,
#   'boygeorg': 0.0,
#   'boyslockeroom': 0.0,
#   'bplsamaritan': 0.0,
#   'bracken': 0.0,
#   'brainer': 0.0,
#   'braintumorawarenessmonth': 0.0,
#   'branch': 0.0,
#   'branden': 0.0,
#   'brandon': 0.0,
#   'brandongraham': 0.0,
#   'brandyarac': 0.0,
#   'brava': 0.0,
#   'brave': 0.4719416793028901,
#   'braveheart': 0.2058650116456393,
#   'braver': 0.16314416183443115,
#   'braveri': 0.06021165601161149,
#   'bravesonsofindia': 0.0,
#   'brazil': 0.2058650116456393,
#   'breakingnew': 0.16314416183443115,
#   'breakthrough': 0.0,
#   'breast': 0.2058650116456393,
#   'breav': 0.0,
#   'bredren': 0.0,
#   'breen': 0.35608796522902986,
#   'breesanna': 0.0,
#   'brendan': 0.0,
#   'brendancarrfcc': 0.0,
#   'brendanwgil': 0.06021165601161149,
#   'brenebrown': 0.0,
#   'bretbaier': 0.0,
#   'brgi': 0.0,
#   'brian': 0.2531554594062104,
#   'brianlehr': 0.0,
#   'brianschatz': 0.0,
#   'briansn': 0.0,
#   'brianstelt': 0.0,
#   'bribe': 0.0,
#   'bride': 0.06021165601161149,
#   'bridgen': 0.0,
#   'bridgeport': 0.0,
#   'brien': 0.0,
#   'brig': 0.0,
#   'bright': 0.0,
#   'brighten': 0.0,
#   'brighteon': 0.0,
#   'brighter': 0.0,
#   'brightsid': 0.0,
#   'brillant': 0.0,
#   'brilliant': 0.2390018771471618,
#   'bristol': 0.0,
#   'british': 0.2779630270117315,
#   'britishsterl': 0.0,
#   'brittani': 0.06021165601161149,
#   'brixton': 0.16314416183443115,
#   'brixtonian': 0.0,
#   'brng': 0.0,
#   'bro': 0.3808955328345509,
#   'brockton': 0.0,
#   'broke': 0.2531554594062104,
#   'broken': 0.2531554594062104,
#   'bronxmc': 0.0,
#   'brooklyn': 0.2992135331587735,
#   'brooklyncowboy': 0.0,
#   'brooklynvegan': 0.0,
#   'brooooo': 0.0,
#   'brotha': 0.06021165601161149,
#   'brother': 0.5717477493186774,
#   'brotherhood': 0.0,
#   'brotherrip': 0.0,
#   'browardsheriff': 0.06021165601161149,
#   'brown': 0.2390018771471618,
#   'browni': 0.0,
#   'bruce': 0.2058650116456393,
#   'brucebourgoin': 0.06021165601161149,
#   'bruner': 0.06021165601161149,
#   'brut': 0.0,
#   'bryan': 0.06021165601161149,
#   'bryant': 0.06021165601161149,
#   'bryanwshepherd': 0.0,
#   'brymo': 0.0,
#   'bsf': 0.2531554594062104,
#   'bso': 0.0,
#   'bsosherifftoni': 0.0,
#   'btr': 0.0,
#   'btsm': 0.0,
#   'btw': 0.10293250582281965,
#   'bubba': 0.0,
#   'buchanan': 0.0,
#   'buckaroo': 0.0,
#   'buckland': 0.0,
#   'buckley': 0.06021165601161149,
#   'buddi': 0.22335581784604286,
#   'bug': 0.0,
#   'bui': 0.13606937132434216,
#   'buildbackbett': 0.0,
#   'buju': 0.0,
#   'bujufan': 0.0,
#   'bull': 0.10293250582281965,
#   'bullshyt': 0.0,
#   'bumbl': 0.0,
#   'bunch': 0.06021165601161149,
#   'bund': 0.0,
#   'bundesliga': 0.06021165601161149,
#   'bunni': 0.10293250582281965,
#   'burgess': 0.06021165601161149,
#   'burial': 0.22335581784604286,
#   'burlap': 0.0,
#   'burlingtonnc': 0.0,
#   'burnden': 0.0,
#   'burnout': 0.0,
#   'burton': 0.10293250582281965,
#   'busfir': 0.06021165601161149,
#   'bushmeat': 0.0,
#   'butch': 0.0,
#   'butcher': 0.0,
#   'butler': 0.10293250582281965,
#   'buyerlead': 0.0,
#   'buzzfe': 0.0,
#   'buzzfeednew': 0.0,
#   'bv': 0.0,
#   'bvg': 0.0,
#   'bx': 0.0,
#   'bye': 0.16314416183443115,
#   'bylin': 0.0,
#   'byrddog': 0.0,
#   'byrn': 0.0,
#   'cabillon': 0.0,
#   'cachesheab': 0.0,
#   'cactaur': 0.0,
#   'cadbi': 0.0,
#   'cadi': 0.0,
#   'cairo': 0.0,
#   'caitograc': 0.0,
#   'cake': 0.06021165601161149,
#   'cakiminow': 0.0,
#   'cal': 0.06021165601161149,
#   'calam': 0.18603557103859614,
#   'calcutta': 0.10293250582281965,
#   'caldwel': 0.0,
#   'calendar': 0.0,
#   'calinan': 0.0,
#   'caller': 0.0,
#   'calvin': 0.0,
#   'cambodia': 0.0,
#   'camden': 0.0,
#   'camdencountynj': 0.0,
#   'came': 0.3919005826842352,
#   'camel': 0.0,
#   'cameron': 0.0,
#   'cameronboyc': 0.0,
#   'campbellclaret': 0.06021165601161149,
#   'campbeltown': 0.0,
#   'campu': 0.0,
#   'camsur': 0.0,
#   'canadian': 0.18603557103859614,
#   'canadianuk': 0.0,
#   'canara': 0.0,
#   'cancer': 0.42503744818575795,
#   'cancerrip': 0.0,
#   'candacerennick': 0.0,
#   'candacetx': 0.06021165601161149,
#   'candid': 0.06021165601161149,
#   'canhcpakistan': 0.0,
#   'cannon': 0.0,
#   'canon': 0.0,
#   'cantaloup': 0.0,
#   'capitol': 0.0,
#   'capitul': 0.0,
#   'capotreno': 0.0,
#   'cappello': 0.0,
#   'capstoneuk': 0.0,
#   'caption': 0.0,
#   'captiv': 0.0,
#   'captmarkkelli': 0.0,
#   'captsharma': 0.0,
#   'caputo': 0.0,
#   'car': 0.2779630270117315,
#   'card': 0.34193438296998147,
#   'cardiac': 0.06021165601161149,
#   'cardin': 0.0,
#   'cardinaldolan': 0.0,
#   'career': 0.2390018771471618,
#   'caregiv': 0.0,
#   'careless': 0.16314416183443115,
#   'carey': 0.0,
#   'cargil': 0.06021165601161149,
#   'cari': 0.18603557103859614,
#   'carl': 0.0,
#   'carlevecrim': 0.0,
#   'carm': 0.0,
#   'carnet': 0.0,
#   'carnivalgam': 0.0,
#   'carnousti': 0.0,
#   'carolin': 0.06021165601161149,
#   'carolineflack': 0.0,
#   'caroljhedg': 0.0,
#   'carpet': 0.06021165601161149,
#   'carpool': 0.0,
#   'carri': 0.2390018771471618,
#   'carrolton': 0.0,
#   'carryminatiroast': 0.0,
#   'cartoon': 0.0,
#   'cartoonist': 0.0,
#   'cartoonsketch': 0.0,
#   'carveri': 0.0,
#   'casey': 0.0,
#   'cashapp': 0.10293250582281965,
#   'cashappinbio': 0.0,
#   'casino': 0.0,
#   'casket': 0.0,
#   'castellano': 0.0,
#   'casualpoet': 0.06021165601161149,
#   'casualti': 0.2992135331587735,
#   'catalog': 0.0,
#   'catastoprh': 0.0,
#   'catastroph': 0.13606937132434216,
#   'catboygiyuu': 0.0,
#   'catch': 0.2992135331587735,
#   'cath': 0.06021165601161149,
#   'catherinelugg': 0.06021165601161149,
#   'catherinewest': 0.0,
#   'cathol': 0.2889680768614158,
#   'catholiccharm': 0.0,
#   'catholicchurch': 0.0,
#   'catholicedchat': 0.0,
#   'catholicforlif': 0.0,
#   'catholicstl': 0.0,
#   'cati': 0.0,
#   'caught': 0.2660766676572508,
#   'caulimoviru': 0.0,
#   'caus': 0.5099478405662885,
#   'cavali': 0.0,
#   'cavernofam': 0.0,
#   'cbcthenat': 0.0,
#   'cbntweet': 0.0,
#   'cbrewsayso': 0.0,
#   'cbsthismorn': 0.0,
#   'cccfalkland': 0.0,
#   'cclodato': 0.0,
#   'ccpliedpeopledi': 0.0,
#   'cdcemerg': 0.0,
#   'cdcgov': 0.0,
#   'cdmx': 0.0,
#   'cdn': 0.0,
#   'cdnmedia': 0.0,
#   'cdu': 0.0,
#   'cducsubt': 0.0,
#   'cece': 0.0,
#   'ceceal': 0.0,
#   'cecilia': 0.0,
#   'cee': 0.0,
#   'ceexcyn': 0.0,
#   'celebr': 0.42503744818575795,
#   'celia': 0.16314416183443115,
#   'cellphon': 0.0,
#   'censu': 0.0,
#   'centralflorida': 0.0,
#   'centrallabornyc': 0.0,
#   'centuri': 0.13606937132434216,
#   'ceolin': 0.0,
#   'cepivaccin': 0.0,
#   'cerb': 0.0,
#   'cero': 0.0,
#   'certifi': 0.10293250582281965,
#   'cesar': 0.06021165601161149,
#   'cgcc': 0.0,
#   'cgckuwait': 0.0,
#   'ch': 0.10293250582281965,
#   'chadmoor': 0.0,
#   'chafina': 0.0,
#   ...}}

# %%
dict_mourn_es
# Out:
# {'score': {'aaaaa': 0.0,
#   'aalb': 0.0,
#   'aalimentari': 0.0,
#   'aaronri': 0.0,
#   'aatanaci': 0.0,
#   'ab': 0.06144164789582507,
#   'aba': 0.1050351908371534,
#   'abad': 0.138848969719489,
#   'abaj': 0.18983586914878936,
#   'abal': 0.0,
#   'abandon': 0.29487105998594343,
#   'abarrot': 0.06144164789582507,
#   'abasatec': 0.0,
#   'abc': 0.41532976406905475,
#   'abcradiomx': 0.0,
#   'abdo': 0.0,
#   'abdominal': 0.1050351908371534,
#   'abej': 0.0,
#   'aberraci': 0.0,
#   'abiert': 0.3151055725114613,
#   'abiertasqepd': 0.0,
#   'abinad': 0.0,
#   'abisp': 0.0,
#   'able': 0.1050351908371534,
#   'ables': 0.0,
#   'abn': 0.0,
#   'abo': 0.0,
#   'abogadoantoniov': 0.0,
#   'abolicion': 0.0,
#   'abolishic': 0.0,
#   'abon': 0.0,
#   'abra': 0.06144164789582507,
#   'abrac': 0.06144164789582507,
#   'abrahamendiet': 0.06144164789582507,
#   'abran': 0.06144164789582507,
#   'abraz': 0.7370117975648794,
#   'abrazal': 0.0,
#   'abrazosvirtual': 0.0,
#   'abrelosoj': 0.06144164789582507,
#   'abreu': 0.1050351908371534,
#   'abrham': 0.0,
#   'abri': 0.06144164789582507,
#   'abriend': 0.06144164789582507,
#   'abrir': 0.32429224873335016,
#   'abrogaci': 0.0,
#   'abstracci': 0.0,
#   'abu': 0.18983586914878936,
#   'abuel': 0.5227895466147479,
#   'abuela': 0.0,
#   'abuelit': 0.3765472204072866,
#   'abund': 0.18983586914878936,
#   'abus': 0.21007038167430725,
#   'abutidlazof': 0.0,
#   'acad': 0.06144164789582507,
#   'acaec': 0.1050351908371534,
#   'acapulc': 0.0,
#   'acat': 0.24388416055664286,
#   'acatlanpum': 0.0,
#   'accident': 0.24388416055664286,
#   'acearanez': 0.0,
#   'acel': 0.0,
#   'acentral': 0.0,
#   'acentu': 0.0,
#   'acept': 0.33295367746595805,
#   'aceptaci': 0.06144164789582507,
#   'acer': 0.0,
#   'aceved': 0.0,
#   'achac': 0.06144164789582507,
#   'achag': 0.0,
#   'achat': 0.0,
#   'aches': 0.0,
#   'aciert': 0.1050351908371534,
#   'aclar': 0.27151202957013276,
#   'acog': 0.06144164789582507,
#   'acoj': 0.138848969719489,
#   'acomp': 0.46134789871892234,
#   'acondicion': 0.0,
#   'aconsej': 0.0,
#   'acontec': 0.0,
#   'acoraz': 0.1050351908371534,
#   'acoru': 0.0,
#   'acost': 0.1050351908371534,
#   'acostadit': 0.0,
#   'acostumbr': 0.21007038167430725,
#   'acquamarinn': 0.0,
#   'acredit': 0.0,
#   'acritud': 0.0,
#   'act': 0.21007038167430725,
#   'actas': 0.0,
#   'actidtud': 0.0,
#   'actitud': 0.24388416055664286,
#   'actividaddc': 0.0,
#   'actividadparanormal': 0.0,
#   'actriz': 0.06144164789582507,
#   'actuaci': 0.2279184866288042,
#   'actualemnt': 0.0,
#   'actualidadrt': 0.0,
#   'acuarel': 0.0,
#   'acud': 0.1050351908371534,
#   'acuellararauj': 0.0,
#   'acuicultur': 0.0,
#   'acv': 0.0,
#   'ad': 0.06144164789582507,
#   'adamsmithfre': 0.0,
#   'adamw': 0.0,
#   'addy': 0.0,
#   'ade': 0.0,
#   'adecu': 0.16647683873297892,
#   'adecuaci': 0.0,
#   'adel': 0.4379888683031119,
#   'adelacruz': 0.0,
#   'adelamadr': 0.0,
#   'adelant': 0.28364120113917934,
#   'adelgaz': 0.0,
#   'adelut': 0.0,
#   'adem': 0.43372002970543266,
#   'ademgu': 0.0,
#   'ademocrat': 0.1050351908371534,
#   'ades': 0.0,
#   'adesaluddepartamental': 0.0,
#   'adesescal': 0.0,
#   'adher': 0.0,
#   'adhesi': 0.0,
#   'adhier': 0.06144164789582507,
#   'adi': 0.3489193513937967,
#   'adjunt': 0.06144164789582507,
#   'administraci': 0.138848969719489,
#   'administracion': 0.1050351908371534,
#   'admir': 0.2279184866288042,
#   'admiraci': 0.138848969719489,
#   'admiracion': 0.0,
#   'admit': 0.06144164789582507,
#   'adnradiochil': 0.0,
#   'ado': 0.24388416055664286,
#   'adoctrin': 0.06144164789582507,
#   'adolecent': 0.0,
#   'adolf': 0.0,
#   'adolfoalbertoc': 0.0,
#   'adonay': 0.06144164789582507,
#   'adond': 0.0,
#   'adorn': 0.0,
#   'adorni': 0.0,
#   'adquisici': 0.06144164789582507,
#   'adreit': 0.0,
#   'adri': 0.06144164789582507,
#   'adrian': 0.0,
#   'adriana': 0.0,
#   'adrianaluci': 0.0,
#   'adrinhoyt': 0.0,
#   'aduc': 0.0,
#   'adultez': 0.0,
#   'advent': 0.0,
#   'advers': 0.21007038167430725,
#   'advertent': 0.16647683873297892,
#   'advirt': 0.06144164789582507,
#   'advirti': 0.06144164789582507,
#   'aecc': 0.06144164789582507,
#   'aegc': 0.0,
#   'aemprend': 0.0,
#   'aencas': 0.06144164789582507,
#   'aere': 0.0,
#   'aereocco': 0.0,
#   'aeromex': 0.0,
#   'aeronav': 0.0,
#   'aesjogr': 0.0,
#   'aest': 0.0,
#   'aestadelut': 0.0,
#   'aeuropeodelaspym': 0.0,
#   'afan': 0.06144164789582507,
#   'afbetancourt': 0.0,
#   'afeccion': 0.0,
#   'afect': 0.5022110299711415,
#   'afectu': 0.16647683873297892,
#   'afgan': 0.0,
#   'afganist': 0.0,
#   'afich': 0.0,
#   'aficion': 0.1050351908371534,
#   'afiliaci': 0.0,
#   'afirmaci': 0.06144164789582507,
#   'aflig': 0.0,
#   'aflor': 0.0,
#   'afortun': 0.06144164789582507,
#   'afr': 0.0,
#   'afric': 0.0,
#   'afrodit': 0.0,
#   'afroperuan': 0.0,
#   'afuer': 0.24388416055664286,
#   'afuert': 0.0,
#   'agall': 0.0,
#   'agapit': 0.06144164789582507,
#   'agarral': 0.0,
#   'agath': 0.0,
#   'agelv': 0.0,
#   'agenci': 0.16647683873297892,
#   'agenciatelam': 0.0,
#   'agend': 0.18983586914878936,
#   'aglomer': 0.16647683873297892,
#   'agn': 0.0,
#   'agrad': 0.1050351908371534,
#   'agradec': 0.42932743957050423,
#   'agradeci': 0.0,
#   'agrav': 0.1050351908371534,
#   'agre': 0.0,
#   'agred': 0.138848969719489,
#   'agregu': 0.0,
#   'agro': 0.0,
#   'agronom': 0.06144164789582507,
#   'agropecuari': 0.06144164789582507,
#   'agrupacion': 0.0,
#   'aguant': 0.34114668619978916,
#   'agud': 0.06144164789582507,
#   'aguerosergiokun': 0.0,
#   'aguerr': 0.0,
#   'agui': 0.06144164789582507,
#   'aguil': 0.5275253616958224,
#   'aguilarartur': 0.16647683873297892,
#   'aguilarl': 0.0,
#   'aguilarqepd': 0.0,
#   'aguinald': 0.0,
#   'agust': 0.1050351908371534,
#   'agusvbagn': 0.0,
#   'ahdr': 0.0,
#   'ahgggg': 0.0,
#   'ahhhh': 0.0,
#   'ahiii': 0.06144164789582507,
#   'ahir': 0.06144164789582507,
#   'ahond': 0.0,
#   'ahors': 0.0,
#   'ahuev': 0.0,
#   'ahuj': 0.0,
#   'ahum': 0.0,
#   'ahuyent': 0.0,
#   'ahyde': 0.0,
#   'aic': 0.0,
#   'aidesep': 0.0,
#   'aidit': 0.0,
#   'aiell': 0.0,
#   'aiemor': 0.0,
#   'aiki': 0.0,
#   'ailinari': 0.0,
#   'ain': 0.0,
#   'airheadhell': 0.0,
#   'ais': 0.06144164789582507,
#   'aish': 0.16647683873297892,
#   'aishastambouli': 0.16647683873297892,
#   'aislant': 0.0,
#   'ait': 0.0,
#   'aiu': 0.0,
#   'aivans': 0.0,
#   'ajajajajajajajaj': 0.0,
#   'ajajajjaj': 0.0,
#   'ajdjjad': 0.0,
#   'ajedrez': 0.0,
#   'ajen': 0.42932743957050423,
#   'ajenaaa': 0.0,
#   'ajosu': 0.0,
#   'ajoylaurel': 0.0,
#   'ajpn': 0.0,
#   'aju': 0.138848969719489,
#   'ajuntamentsalou': 0.0,
#   'ajur': 0.0,
#   'akik': 0.0,
#   'akikok': 0.0,
#   'akjsjs': 0.0,
#   'ala': 0.28364120113917934,
#   'alab': 0.06144164789582507,
#   'alajuel': 0.0,
#   'alamal': 0.0,
#   'alambr': 0.0,
#   'alarc': 0.0,
#   'alarcon': 0.0,
#   'alard': 0.0,
#   'alarmaceut': 0.0,
#   'alas': 0.138848969719489,
#   'alavez': 0.2279184866288042,
#   'alb': 0.0,
#   'alba': 0.16647683873297892,
#   'albacet': 0.06144164789582507,
#   'albani': 0.0,
#   'albert': 0.47513319331813686,
#   'albertoem': 0.0,
#   'albertoenseri': 0.1050351908371534,
#   'albertok': 0.06144164789582507,
#   'albertokauam': 0.24388416055664286,
#   'albertsmismith': 0.0,
#   'albiol': 0.16647683873297892,
#   'albiolmi': 0.0,
#   'albor': 0.0,
#   'albrecht': 0.0,
#   'alcadescorrupt': 0.0,
#   'alcagirardot': 0.0,
#   'alcal': 0.2279184866288042,
#   'alcald': 0.5022110299711415,
#   'alcaldeledezm': 0.0,
#   'alcaldes': 0.24388416055664286,
#   'alcaldi': 0.1050351908371534,
#   'alcaldiaarmeni': 0.0,
#   'alcaldiagy': 0.0,
#   'alcaldiaitagui': 0.0,
#   'alcaldiamhmx': 0.0,
#   'alcalin': 0.0,
#   'alcaz': 0.0,
#   'alcidesraymem': 0.06144164789582507,
#   'alco': 0.0,
#   'alcoc': 0.0,
#   'alcoy': 0.06144164789582507,
#   'aldan': 0.0,
#   'alde': 0.0,
#   'aldegund': 0.0,
#   'aldi': 0.0,
#   'aldo': 0.0,
#   'aldubxkschalleng': 0.0,
#   'aled': 0.06144164789582507,
#   'aledrei': 0.0,
#   'aleg': 0.06144164789582507,
#   'alegr': 0.38867639197633297,
#   'alegral': 0.0,
#   'alegrart': 0.0,
#   'alejand': 0.0,
#   'alejandrosanz': 0.3053258084524684,
#   'alekab': 0.0,
#   'alemchalecomx': 0.0,
#   'alent': 0.16647683873297892,
#   'alentej': 0.0,
#   'aleortizglez': 0.0,
#   'alert': 0.3999062508230973,
#   'alertagap': 0.0,
#   'alertanews': 0.0,
#   'ales': 0.138848969719489,
#   'aless': 0.446181877036943,
#   'alessaalegr': 0.0,
#   'alessandr': 0.3489193513937967,
#   'alessandrifelip': 0.06144164789582507,
#   'alevig': 0.0,
#   'alex': 0.484706929134733,
#   'alexand': 0.0,
#   'alexandr': 0.138848969719489,
#   'alexcd': 0.0,
#   'alexh': 0.0,
#   'alexiarivasserr': 0.0,
#   'alexis': 0.138848969719489,
#   'alexlecqui': 0.0,
#   'alexlequi': 0.2279184866288042,
#   'alexlequiodep': 0.0,
#   'alexocl': 0.0,
#   'alexqu': 0.0,
#   'alferdezprens': 0.0,
#   'alfombr': 0.0,
#   'alfred': 0.06144164789582507,
#   'alfredit': 0.0,
#   'alfredoar': 0.24388416055664286,
#   'alfredoasti': 0.0,
#   'alfredodelmazoeselacecin': 0.0,
#   'alfredoilomort': 0.0,
#   'alfredopelmaz': 0.0,
#   'algecir': 0.06144164789582507,
#   'algi': 0.0,
#   'algod': 0.0,
#   'ali': 0.1050351908371534,
#   'alianc': 0.16647683873297892,
#   'aliancistafalleci': 0.0,
#   'alianz': 0.18983586914878936,
#   'alianzalim': 0.0,
#   'alic': 0.1050351908371534,
#   'alicantemis': 0.0,
#   'aliceavizandum': 0.0,
#   'alich': 0.28364120113917934,
#   'alici': 0.0,
#   'alient': 0.16647683873297892,
#   'aliger': 0.0,
#   'alim': 0.06144164789582507,
#   'alit': 0.0,
#   'alitomorenoc': 0.06144164789582507,
#   'aliveandfre': 0.0,
#   'aljaraf': 0.0,
#   'all': 0.4379888683031119,
#   'alla': 0.18983586914878936,
#   'allan': 0.0,
#   'allanklownz': 0.16647683873297892,
#   'allanrodriguez': 0.0,
#   'allboys': 0.06144164789582507,
#   'alleg': 0.37009800248098323,
#   'allend': 0.1050351908371534,
#   'allengkat': 0.0,
#   'alma': 0.5179009372187973,
#   'almac': 0.0,
#   'almamis': 0.0,
#   'almas': 0.21007038167430725,
#   'almaxeneiz': 0.0,
#   'almer': 0.0,
#   'almit': 0.0,
#   'almorz': 0.06144164789582507,
#   'aloj': 0.0,
#   'alomejor': 0.0,
#   'alons': 0.1050351908371534,
#   'alopresident': 0.1050351908371534,
#   'alp': 0.0,
#   'alpac': 0.0,
#   'alpers': 0.0,
#   'alphabet': 0.0,
#   'altaresmonc': 0.0,
#   'altas': 0.138848969719489,
#   'altavozconlalocastill': 0.0,
#   'alteraci': 0.06144164789582507,
#   'altisim': 0.0,
#   'alto': 0.4501180398721585,
#   'altoinvasion': 0.0,
#   'altruist': 0.0,
#   'altur': 0.33295367746595805,
#   'altuv': 0.0,
#   'alucin': 0.06144164789582507,
#   'alumn': 0.138848969719489,
#   'alumnis': 0.0,
#   'alvar': 0.29487105998594343,
#   'alvarezpecol': 0.0,
#   'alvarosanc': 0.0,
#   'alvarosarc': 0.0,
#   'alvarouribevel': 0.06144164789582507,
#   'alvis': 0.0,
#   'alvisepf': 0.06144164789582507,
#   'alza': 0.24388416055664286,
#   'am': 0.5409046714602572,
#   'amab': 0.1050351908371534,
#   'amabil': 0.0,
#   'amabl': 0.18983586914878936,
#   'amad': 0.32429224873335016,
#   'amadoelquelole': 0.0,
#   'amaerx': 0.0,
#   'amam': 0.18983586914878936,
#   'aman': 0.0,
#   'amand': 0.1050351908371534,
#   'amanec': 0.1050351908371534,
#   'amaneci': 0.0,
#   'amant': 0.1050351908371534,
#   'amar': 0.1050351908371534,
#   'amarg': 0.138848969719489,
#   'amargur': 0.0,
#   'amatitl': 0.0,
#   'amaz': 0.16647683873297892,
#   'amazona': 0.0,
#   'ambas': 0.1050351908371534,
#   'ambigu': 0.0,
#   'ambition': 0.0,
#   'ambos': 0.2279184866288042,
#   'ambulantegiracontig': 0.0,
#   'amen': 0.21007038167430725,
#   'amer': 0.1050351908371534,
#   'americ': 0.06144164789582507,
#   'american': 0.21007038167430725,
#   'americasur': 0.0,
#   'americodegrazi': 0.0,
#   'americogarz': 0.0,
#   'amerit': 0.0,
#   'amhm': 0.0,
#   'ami': 0.0,
#   'amig': 0.8378951191262092,
#   'amigdalitis': 0.0,
#   'amigosqepd': 0.0,
#   'amiguit': 0.16647683873297892,
#   'amigxs': 0.16647683873297892,
#   'amist': 0.24388416055664286,
#   'amistad': 0.24388416055664286,
#   'amit': 0.0,
#   'amlo': 0.27151202957013276,
#   'amloelfracasopresidencial': 0.0,
#   'amloelpeorpresidentedelmund': 0.0,
#   'amnistiaperu': 0.0,
#   'amonton': 0.0,
#   'amor': 0.4907690874663295,
#   'amordaz': 0.0,
#   'amordemadr': 0.0,
#   'amorel': 0.0,
#   'amorrr': 0.0,
#   'amortiguaci': 0.0,
#   'amos': 0.4421407375789359,
#   'ampar': 0.06144164789582507,
#   'ampe': 0.0,
#   'ampl': 0.0,
#   'amu': 0.0,
#   'ana': 0.5866176020815942,
#   'anabeluni': 0.0,
#   'anacatyhdz': 0.0,
#   'anaech': 0.0,
#   'anaelim': 0.0,
#   'anajosebb': 0.0,
#   'anakin': 0.0,
#   'anal': 0.06144164789582507,
#   'analfabet': 0.0,
#   'analgesi': 0.0,
#   'analiz': 0.2279184866288042,
#   'analun': 0.0,
#   'anamariabeash': 0.0,
#   'anamariagazmuri': 0.0,
#   'anamarorihuel': 0.0,
#   'anaobregon': 0.18983586914878936,
#   'anaobregoncf': 0.0,
#   'anaobregonfancl': 0.0,
#   'anap': 0.0,
#   'anapeupon': 0.0,
#   'anarun': 0.0,
#   'anas': 0.1050351908371534,
#   'ancarjac': 0.0,
#   'ancash': 0.0,
#   'andab': 0.1050351908371534,
#   'andahuaylin': 0.0,
#   'andalucescstv': 0.0,
#   'andaluciasinvox': 0.0,
#   'andaluciavox': 0.0,
#   'andan': 0.21007038167430725,
#   'andand': 0.138848969719489,
#   'andant': 0.0,
#   'andar': 0.27151202957013276,
#   'andars': 0.0,
#   'andcompart': 0.0,
#   'ande': 0.0,
#   'andin': 0.1050351908371534,
#   'andr': 0.21007038167430725,
#   'andreachaveztr': 0.1050351908371534,
#   'andreavelab': 0.06144164789582507,
#   'andresroj': 0.0,
#   'andrestovarp': 0.0,
#   'anduv': 0.0,
#   'andval': 0.0,
#   'andy': 0.0,
#   'andykusnetzoff': 0.0,
#   'andystalm': 0.0,
#   'ane': 0.0,
#   'anecd': 0.0,
#   'anefchil': 0.0,
#   'anefvalparais': 0.0,
#   'anestes': 0.0,
#   'aneurism': 0.2279184866288042,
#   'ange': 0.0,
#   'angelamrobled': 0.06144164789582507,
#   'angeldebritook': 0.0,
#   'angelgcoll': 0.0,
#   'angelot': 0.0,
#   'angelus': 0.0,
#   'angiemoyam': 0.0,
#   'angin': 0.0,
#   'angiotc': 0.0,
#   'angryblacklady': 0.0,
#   'anguit': 0.0,
#   'anhel': 0.138848969719489,
#   'anigptv': 0.06144164789582507,
#   'anikin': 0.0,
#   'anim': 0.3563127078817687,
#   'animalesexot': 0.0,
#   'animalessilvestr': 0.0,
#   'animalit': 0.0,
#   'animat': 0.06144164789582507,
#   'aniquil': 0.0,
#   'anit': 0.0,
#   'anitaobregon': 0.32429224873335016,
#   'anitazenok': 0.0,
#   'aniversari': 0.21007038167430725,
#   'ank': 0.06144164789582507,
#   'ankar': 0.0,
#   'anlik': 0.0,
#   'anme': 0.0,
#   'anonim': 0.0,
#   'anonyosoy': 0.0,
#   'anormal': 0.0,
#   'anosep': 0.0,
#   'anpe': 0.0,
#   'anseat': 0.0,
#   'ansiol': 0.0,
#   'antaki': 0.0,
#   'antanasmockus': 0.0,
#   'anteced': 0.0,
#   'anteoj': 0.0,
#   'antepus': 0.0,
#   'anterior': 0.24388416055664286,
#   'antiaml': 0.0,
#   'anticipaci': 0.06144164789582507,
#   'antigu': 0.06144164789582507,
#   'antinatural': 0.06144164789582507,
#   'antinflamatori': 0.0,
#   'antivacun': 0.0,
#   'antizombi': 0.0,
#   'anto': 0.06144164789582507,
#   'antofagast': 0.1050351908371534,
#   'antoin': 0.0,
#   'antoni': 0.39439532536178357,
#   'antonioabog': 0.0,
#   'antonioattolini': 0.0,
#   'antonioeluston': 0.0,
#   'antonioluqu': 0.0,
#   'antonioseque': 0.0,
#   'antonioveg': 0.0,
#   'anwaakong': 0.0,
#   'any': 0.0,
#   'anyway': 0.06144164789582507,
#   'anz': 0.0,
#   'anza': 0.06144164789582507,
#   'anzas': 0.16647683873297892,
#   'anzel': 0.0,
#   'apa': 0.1050351908371534,
#   'apachurr': 0.06144164789582507,
#   'apagayvamonosfs': 0.0,
#   'apal': 0.0,
#   'apan': 0.0,
#   'apapach': 0.0,
#   'aparc': 0.0,
#   'aparient': 0.0,
#   'apasion': 0.138848969719489,
#   'apdrm': 0.0,
#   'apep': 0.0,
#   'apetec': 0.0,
#   'api': 0.0,
#   'apiad': 0.0,
#   'apit': 0.0,
#   'aplaud': 0.2279184866288042,
#   'aplaudoanuestrosher': 0.0,
#   'aplaus': 0.2279184866288042,
#   'apliquens': 0.0,
#   'apm': 0.06144164789582507,
#   'apne': 0.0,
#   'apodac': 0.1050351908371534,
#   'apoder': 0.06144164789582507,
#   'apol': 0.0,
#   'aporofobi': 0.0,
#   'apost': 0.138848969719489,
#   'apoy': 0.5275253616958224,
#   'apoyandot': 0.0,
#   'apoyocie': 0.0,
#   'apple': 0.2279184866288042,
#   'apreci': 0.33295367746595805,
#   'aprecol': 0.0,
#   'aprendi': 0.1050351908371534,
#   'apret': 0.16647683873297892,
#   'apriet': 0.06144164789582507,
#   'aprist': 0.06144164789582507,
#   'aprovech': 0.37009800248098323,
#   'aprovechart': 0.0,
#   'aprox': 0.1050351908371534,
#   'aprueb': 0.1050351908371534,
#   'apucoficial': 0.0,
#   'apuntal': 0.0,
#   'aquam': 0.0,
#   'aquelarr': 0.0,
#   'aquell': 0.38867639197633297,
#   'aquevequ': 0.0,
#   'aqyi': 0.0,
#   'ar': 0.42932743957050423,
#   'arac': 0.0,
#   'aragu': 0.0,
#   'araizal': 0.0,
#   'aramburu': 0.0,
#   'aran': 0.16647683873297892,
#   'aranchaglezlay': 0.0,
#   'aranjuez': 0.0,
#   'aranohisoc': 0.0,
#   'arauc': 0.06144164789582507,
#   'araven': 0.06144164789582507,
#   'arbery': 0.0,
#   'arcadi': 0.1050351908371534,
#   'arcadioguzm': 0.21007038167430725,
#   'archiv': 0.0,
#   'arcil': 0.0,
#   'arcoiris': 0.0,
#   'arcos': 0.0,
#   'ard': 0.0,
#   'arda': 0.0,
#   'ardesangr': 0.0,
#   'ardkeengroc': 0.0,
#   'ardor': 0.0,
#   'ardu': 0.138848969719489,
#   'are': 0.1050351908371534,
#   'arem': 0.138848969719489,
#   'arenaoficial': 0.06144164789582507,
#   'arener': 0.0,
#   'arenezugasti': 0.0,
#   'areng': 0.0,
#   'ares': 0.0,
#   'arez': 0.0,
#   'arfatravel': 0.0,
#   'argand': 0.0,
#   'argent': 0.0,
#   'argentinop': 0.0,
#   'argmed': 0.0,
#   'ariel': 0.06144164789582507,
#   'arielamay': 0.0,
#   'arielr': 0.0,
#   'ariz': 0.0,
#   'arla': 0.06144164789582507,
#   'arle': 0.0,
#   'armad': 0.27151202957013276,
#   'armador': 0.0,
#   'armand': 0.24388416055664286,
#   'armarc': 0.0,
#   'armoni': 0.0,
#   'arnetonlin': 0.0,
#   'arnold': 0.0,
#   'arnos': 0.06144164789582507,
#   'arobertomosi': 0.0,
#   'arobertosanchez': 0.0,
#   'arol': 0.0,
#   'aron': 0.1050351908371534,
#   'arq': 0.0,
#   'arquer': 0.06144164789582507,
#   'arquitectur': 0.0,
#   'arranc': 0.21007038167430725,
#   'arrancaloy': 0.0,
#   'arrancart': 0.0,
#   'arras': 0.0,
#   'arrastr': 0.138848969719489,
#   'arrebat': 0.18983586914878936,
#   'arregl': 0.18983586914878936,
#   'arrendatari': 0.0,
#   'arrest': 0.18983586914878936,
#   'arriagadap': 0.0,
#   'arrib': 0.4103609992896222,
#   'arriesg': 0.28364120113917934,
#   'arro': 0.0,
#   'arrodill': 0.0,
#   'arrog': 0.1050351908371534,
#   'arrufat': 0.0,
#   'arruinart': 0.0,
#   'art': 0.32429224873335016,
#   'artaz': 0.0,
#   'arteagamassieu': 0.0,
#   'artecu': 0.0,
#   'artemisi': 0.0,
#   'artes': 0.06144164789582507,
#   'artesan': 0.0,
#   'articul': 0.18983586914878936,
#   'artii': 0.0,
#   'artist': 0.27151202957013276,
#   'artritis': 0.0,
#   'artrosis': 0.0,
#   'artur': 0.24388416055664286,
#   'arturofior': 0.0,
#   'aruin': 0.0,
#   'aruser': 0.0,
#   'arvm': 0.0,
#   'asambl': 0.0,
#   'asamble': 0.16647683873297892,
#   'asambleaces': 0.0,
#   'ascendi': 0.0,
#   'asco': 0.29487105998594343,
#   'ascondolent': 0.0,
#   'asedi': 0.06144164789582507,
#   'asesin': 0.3489193513937967,
#   'asesoriadeconfi': 0.0,
#   'asetur': 0.0,
#   'asfibolivi': 0.0,
#   'asfixi': 0.06144164789582507,
#   'asfixia': 0.0,
#   'ash': 0.0,
#   'ashkenazim': 0.0,
#   'asignaci': 0.06144164789582507,
#   'asimil': 0.06144164789582507,
#   'asin': 0.0,
#   'asinti': 0.0,
#   'asistent': 0.1050351908371534,
#   'asisti': 0.0,
#   'asmat': 0.0,
#   'asnogaby': 0.0,
#   'asoc': 0.0,
#   'asociaci': 0.16647683873297892,
#   'asocolpat': 0.0,
#   'asombr': 0.16647683873297892,
#   'aspect': 0.16647683873297892,
#   'aspir': 0.06144164789582507,
#   'aspiraci': 0.0,
#   'asque': 0.0,
#   'asquer': 0.1050351908371534,
#   'asri': 0.0,
#   'assim': 0.0,
#   'aste': 0.06144164789582507,
#   'astridperezbat': 0.0,
#   'asturizag': 0.0,
#   'asuet': 0.0,
#   'asum': 0.18983586914878936,
#   'atalant': 0.18983586914878936,
#   'ataquealostitan': 0.0,
#   'atas': 0.0,
#   'atavi': 0.21007038167430725,
#   'atcobembibr': 0.0,
#   'ate': 0.27151202957013276,
#   'ateneagow': 0.0,
#   'atent': 0.27151202957013276,
#   'aterriz': 0.0,
#   'atin': 0.1050351908371534,
#   'atisb': 0.0,
#   'atletassv': 0.06144164789582507,
#   'atleticodemadr': 0.0,
#   'atm': 0.0,
#   'atmosf': 0.0,
#   'atmosfer': 0.0,
#   'atont': 0.0,
#   'atorment': 0.0,
#   'atqu': 0.0,
#   'atrac': 0.0,
#   'atrap': 0.1050351908371534,
#   'atraves': 0.2279184866288042,
#   'atrev': 0.18983586914878936,
#   'atuner': 0.0,
#   'audici': 0.1050351908371534,
#   'auditor': 0.0,
#   'aug': 0.0,
#   'august': 0.06144164789582507,
#   'aul': 0.06144164789582507,
#   'aument': 0.37009800248098323,
#   'aun': 0.37009800248098323,
#   'aunk': 0.0,
#   'aunq': 0.06144164789582507,
#   'aunqu': 0.42014076334861516,
#   'auqu': 0.0,
#   'aur': 0.16647683873297892,
#   'aureli': 0.0,
#   'aurorastral': 0.0,
#   'ausenci': 0.18983586914878936,
#   'ausjal': 0.0,
#   'auspici': 0.0,
#   'autism': 0.0,
#   'autoaisl': 0.0,
#   'autoconfin': 0.0,
#   'autoconvonc': 0.0,
#   'autocr': 0.138848969719489,
#   'autodiagnost': 0.0,
#   'autoflagel': 0.0,
#   'autoimpuest': 0.0,
#   'automatiz': 0.0,
#   'autonom': 0.06144164789582507,
#   'autopromov': 0.0,
#   'autoreproch': 0.0,
#   'autorizaci': 0.0,
#   'autostalke': 0.0,
#   'avanz': 0.27151202957013276,
#   'avecill': 0.0,
#   'aveconej': 0.0,
#   'avelin': 0.0,
#   'aven': 0.138848969719489,
#   'avengers': 0.06144164789582507,
#   'aver': 0.0,
#   'aves': 0.0,
#   'avient': 0.0,
#   'avilez': 0.0,
#   'avilezraul': 0.0,
#   'avionet': 0.0,
#   'avism': 0.0,
#   'avnve': 0.0,
#   'axelsanrom': 0.0,
#   'axist': 0.0,
#   'aya': 0.06144164789582507,
#   'ayal': 0.06144164789582507,
#   'ayb': 0.0,
#   'ayer': 0.5531979294004419,
#   'ayquip': 0.06144164789582507,
#   'ayrshir': 0.0,
#   'aysen': 0.0,
#   'aytoxalap': 0.0,
#   'ayudart': 0.0,
#   'ayudit': 0.0,
#   'ayuntamientov': 0.06144164789582507,
#   'ayy': 0.06144164789582507,
#   'az': 0.27151202957013276,
#   'azar': 0.1050351908371534,
#   'azos': 0.0,
#   'aztec': 0.06144164789582507,
#   'azul': 0.16647683873297892,
#   'azulcrem': 0.06144164789582507,
#   'azulin': 0.0,
#   'azulon': 0.1050351908371534,
#   'b': 0.46839725108880614,
#   'bacala': 0.0,
#   'bachill': 0.0,
#   'bacteri': 0.06144164789582507,
#   'badalon': 0.24388416055664286,
#   'badalones': 0.0,
#   'badgalaej': 0.0,
#   'badodecuarenten': 0.0,
#   'bai': 0.06144164789582507,
#   'bail': 0.3563127078817687,
#   'bailarin': 0.0,
#   'bailecit': 0.0,
#   'bajacaliforni': 0.0,
#   'bajacalifornian': 0.0,
#   'bajit': 0.06144164789582507,
#   'bajon': 0.0,
#   'bal': 0.25832686941449845,
#   'balazot': 0.0,
#   'balc': 0.18983586914878936,
#   'balcaz': 0.0,
#   'balcon': 0.21007038167430725,
#   'bald': 0.0,
#   'baldy': 0.0,
#   'ballest': 0.06144164789582507,
#   'ballet': 0.0,
#   'balompi': 0.06144164789582507,
#   'baloncest': 0.1050351908371534,
#   'baluart': 0.0,
#   'bancadaapp': 0.1050351908371534,
#   'bancadasuperr': 0.0,
#   'bancarib': 0.0,
#   'bancom': 0.0,
#   'bandejaqepd': 0.0,
#   'bander': 0.4576963063878823,
#   'banderaz': 0.0,
#   'bandit': 0.0,
#   'banesc': 0.2279184866288042,
#   'banquer': 0.0,
#   'banzasguillerm': 0.0,
#   'baradit': 0.1050351908371534,
#   'barahon': 0.18983586914878936,
#   'baraj': 0.0,
#   'barbieanay': 0.0,
#   'barbierabr': 0.06144164789582507,
#   'bard': 0.06144164789582507,
#   'bardal': 0.0,
#   'bari': 0.0,
#   'barist': 0.0,
#   'barlett': 0.0,
#   'barmilc': 0.0,
#   'barneche': 0.0,
#   'barniz': 0.1050351908371534,
#   'baronjimen': 0.0,
#   'barr': 0.1050351908371534,
#   'barrant': 0.0,
#   'barrender': 0.0,
#   'barrig': 0.1050351908371534,
#   'barriobajer': 0.0,
#   'barriobaroj': 0.0,
#   'barriosal': 0.0,
#   'barrymor': 0.06144164789582507,
#   'bartlett': 0.0,
#   'barttlet': 0.0,
#   'barymont': 0.0,
#   'basquetbol': 0.0,
#   'basquetebrasil': 0.0,
#   'bassi': 0.0,
#   'bastadecuarenten': 0.21007038167430725,
#   'bastill': 0.0,
#   'baston': 0.0,
#   'basult': 0.0,
#   'basural': 0.0,
#   'basurer': 0.06144164789582507,
#   'bat': 0.24388416055664286,
#   'batall': 0.41532976406905475,
#   'batfem': 0.0,
#   'bati': 0.0,
#   'batiscatul': 0.0,
#   'batm': 0.138848969719489,
#   'batmantheanimatedseri': 0.06144164789582507,
#   'baulazul': 0.0,
#   'baylin': 0.0,
#   'bbcr': 0.0,
#   'bbva': 0.0,
#   'bby': 0.0,
#   'bc': 0.06144164789582507,
#   'bcbg': 0.0,
#   'bcg': 0.0,
#   'bci': 0.0,
#   'bcn': 0.0,
#   'bcs': 0.1050351908371534,
#   'bcstm': 0.0,
#   'bdpalac': 0.28364120113917934,
#   'bdptv': 0.06144164789582507,
#   'beatriz': 0.06144164789582507,
#   'beatrizbecerrab': 0.1050351908371534,
#   'beatrizsestayod': 0.0,
#   'beavallem': 0.0,
#   'bebeshit': 0.0,
#   'bebit': 0.0,
#   'bec': 0.06144164789582507,
#   'begonavillacis': 0.0,
#   'behamen': 0.0,
#   'beibi': 0.0,
#   'beisbol': 0.06144164789582507,
#   'beit': 0.0,
#   'beky': 0.0,
#   'beldum': 0.0,
#   'belfior': 0.0,
#   'belgic': 0.0,
#   'belif': 0.0,
#   'belifans': 0.0,
#   'belindapanam': 0.0,
#   'belindapop': 0.21007038167430725,
#   'bell': 0.25832686941449845,
#   'belli': 0.0,
#   'belmont': 0.27151202957013276,
#   'beltr': 0.06144164789582507,
#   'beluhughess': 0.0,
#   'bembibr': 0.1050351908371534,
#   'ben': 0.3489193513937967,
#   'benavid': 0.0,
#   'bendiciendosobr': 0.0,
#   'bendicion': 0.34114668619978916,
#   'bendig': 0.28364120113917934,
#   'bendit': 0.18983586914878936,
#   'benedetti': 0.0,
#   'beneficiari': 0.0,
#   'benj': 0.0,
#   'benjaminfzunig': 0.0,
#   'benlagunass': 0.0,
#   'benlagunasspr': 0.0,
#   'bercian': 0.0,
#   'berenic': 0.0,
#   ...}}

# %% [markdown]
# # Classifier with emoticons

# %% [markdown]
# Proposed features: Number of tokens, number of mourning tokens, number of not mourning tokens, sum of mourning lexicon token values, sum of not mourning lexicon token values, mourning token percentage and not mourning token percentage. Additionally the tag variable is set to 1 as mourning and 0 as not mourning

# %%
#Here we create the features for the datapoints
df_en = create_features(df_en,dict_mourn_en,dict_mourn_en)
df_es = create_features(df_es,dict_mourn_es,dict_mourn_es)

cols = ['NUM_TOKENS','COUNT_MOURN','SUM_MOURN','COUNT_NOMOURN','SUM_NOMOURN','MOURN_PERC','NOMOURN_PERC','Y']

#Here we create the X and y objects for the models
X, y = process_df(df_en,cols)
X_es, y_es = process_df(df_es,cols)

#Here we compare the results for each model on each language
result = get_results(X,y,23,0.25)
result_es = get_results(X_es,y_es,23,0.25)
# Out:
# <ipython-input-3-998d1b7c312d>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NUM_TOKENS'] = df['text'].apply(lambda text: len(text))
# <ipython-input-3-998d1b7c312d>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COUNT_MOURN'] = df['text'].apply(lambda text: count_words_dictionary(text,mourn_dic))
# <ipython-input-3-998d1b7c312d>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SUM_MOURN'] = df['text'].apply(lambda text: sum_words_dictionary(text,mourn_dic))
# <ipython-input-3-998d1b7c312d>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COUNT_NOMOURN'] = df['text'].apply(lambda text: count_words_dictionary(text,nomourn_dic))
# <ipython-input-3-998d1b7c312d>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SUM_NOMOURN'] = df['text'].apply(lambda text: sum_words_dictionary(text,nomourn_dic))
# <ipython-input-3-998d1b7c312d>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MOURN_PERC'] = df['COUNT_MOURN']/df['NUM_TOKENS']
# <ipython-input-3-998d1b7c312d>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NOMOURN_PERC'] = df['COUNT_NOMOURN']/df['NUM_TOKENS']
# <ipython-input-3-998d1b7c312d>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y']=np.where(df['tag'] == 'mourning',1,0)

# %% [markdown]
# English results with emoticons

# %%
result
# Out:
#   Model  Precision    Recall  F1 Score
# 0    NB   0.884704  0.873293  0.878961
# 1    LR   0.907176  0.882398  0.894615
# 2    DT   0.867370  0.873293  0.870321
# 3    RF   0.866667  0.897572  0.881849

# %% [markdown]
# Spanish results with emoticons

# %%
result_es
# Out:
#   Model  Precision    Recall  F1 Score
# 0    NB   0.867876  0.833852  0.850524
# 1    LR   0.891909  0.878034  0.884917
# 2    DT   0.844319  0.836963  0.840625
# 3    RF   0.864932  0.868699  0.866812

# %% [markdown]
# It can be noted that for both languages the logistic regression model is the best option according to all the metrics, this model is followed in order of the F1 score by the Random Forest for both languages. The other two models vary their ranking according to language but do not present as good results.
#
# Additionally, it can be noted that the scores in English are better than those in Spanish, this may be due to the fact that the normalization techniques (stemming) for English are better developed and therefore the lexicon created is better.

# %% [markdown]
# Feature importance for the Logistic Regression

# %%
_, _, lr = train_model(X,y,23,0.25,'LR')
lr_coef = lr.coef_
lr_int = lr.intercept_

print('English model feature importance: ',lr_coef,lr_int)

_, _, lr = train_model(X_es,y_es,23,0.25,'LR')
lr_coef = lr.coef_
lr_int = lr.intercept_

print('Spanish model feature importance: ',lr_coef,lr_int)
# Out:
# English model feature importance:  [[-0.11455891  0.36606365 -0.24774548  0.36606365 -0.24774548  3.1910248
#    3.1910248 ]] [-3.98454802]
# Spanish model feature importance:  [[-0.14050759  0.41965503 -0.3440956   0.41965503 -0.3440956   2.99895694
#    2.99895694]] [-4.12106409]

# %%
cols
# Out:
# ['NUM_TOKENS',
#  'COUNT_MOURN',
#  'SUM_MOURN',
#  'COUNT_NOMOURN',
#  'SUM_NOMOURN',
#  'MOURN_PERC',
#  'NOMOURN_PERC',
#  'Y']

# %% [markdown]
# It can be noted that for both languages the most important variables are the percentage of mourning tokens and percentage of not mourning tokens, with values around 3 for both features in both languages.

# %% [markdown]
# Feature importance Random Forest

# %%
perm_importance = get_rfimportance(X,y,23,0.25)
#sorted_idx = perm_importance.importances_mean.argsort()
plt.barh(cols[:-1], perm_importance.importances_mean)
plt.xlabel("Permutation Importance")
plt.show()

# %%
perm_importance = get_rfimportance(X_es,y_es,23,0.25)
#sorted_idx = perm_importance.importances_mean.argsort()
plt.barh(cols[:-1], perm_importance.importances_mean)
plt.xlabel("Permutation Importance")
plt.show()

# %% [markdown]
# It can be noted that in accordance with the importances given by the logistic regression, the most important features are once again the percentages of mourning and non-mourning tokens. This indicates that these variables were key to the good performance of the developed classifiers.

# %% [markdown]
# # Classifier without emoticons

# %% [markdown]
# Point 4 without emoticons will be done on a different notebook since the change will be made during the processing of text, by completely removing the emojis from the tokens obtained. This modification will be implemented in a change of the keep_emojis parameter of the clean_up_pipeline function (from True to False).

# %% [markdown]
# # Final Conclusions

# %% [markdown]
# In general terms we can see that the logistic model remains the best model out of the 4 compared, additionally we can see that the results improve for the mourning classifier when we keep the emoticons in the tweet as terms. Finally we argue that the designed variables are proven to be effective for the task, obtaining a F1 Score slightly over 0.89 in the english classifier and slightly below it for the spanish classifier.
#
# As said before, it makes sense that the english classifier works better, this is due because the normalization techniques are more advanced in development for english and therefore the resulting lexicon is better.
